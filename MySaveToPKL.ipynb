# %%
# this script just takes the input root files and converts them into pkl
# using deprecated uproot3 instead of uproot, as we are not needing high performance from this package, just using it to convert the data
# please neglect warning messages caused by uproot3

import uproot
import configparser
import ast
from Functions import checkCreateDir
from colorama import init, Fore
init(autoreset = True)

# %%
config = configparser.ConfigParser()
config.read('MyConfig.txt')
inputFiles = ast.literal_eval(config.get('config', 'inputFiles'))
dfPath = config.get('config', 'dfPath')
print (format('Output directory: ' + Fore.GREEN + dfPath), checkCreateDir(dfPath))

for i in inputFiles:
    inFile = config.get('config', 'ntuplePath') + i + '.root'
    print('Loading ' + inFile)
    theFile = uproot.open(inFile)
    if theFile.keys()!=[]:
        tree = theFile['Nominal']

        Nevents = tree.numentries
        print('Number of events in ' + inFile, '\t' + str(Nevents))
        if Nevents == 0:
            print(format(Fore.RED + 'Ignoring empty file '), i)
            continue

        DF = tree.pandas.df()
        outFile = dfPath + i + '_DF.pkl'
        DF.to_pickle(outFile)
        print('Saved ' + outFile)
    else:
        print("NO Keys in ", i)
# Out:
# Output directory: ../DataFrames/  (already there)
# Loading ../Files/INPUT/Zjets-10.root
# Number of events in ../Files/INPUT/Zjets-10.root 	316
# Saved ../DataFrames/Zjets-10_DF.pkl
# Loading ../Files/INPUT/Wjets-3.root
# Number of events in ../Files/INPUT/Wjets-3.root 	46
# Saved ../DataFrames/Wjets-3_DF.pkl
# Loading ../Files/INPUT/Zjets-11.root
# Number of events in ../Files/INPUT/Zjets-11.root 	1
# Saved ../DataFrames/Zjets-11_DF.pkl
# Loading ../Files/INPUT/ttbar-0.root
# Number of events in ../Files/INPUT/ttbar-0.root 	82441
# Saved ../DataFrames/ttbar-0_DF.pkl
# Loading ../Files/INPUT/Zjets-4.root
# Number of events in ../Files/INPUT/Zjets-4.root 	861062
# Saved ../DataFrames/Zjets-4_DF.pkl
# Loading ../Files/INPUT/stop-1.root
# Number of events in ../Files/INPUT/stop-1.root 	9016
# Saved ../DataFrames/stop-1_DF.pkl
# Loading ../Files/INPUT/ttbar-4.root
# Number of events in ../Files/INPUT/ttbar-4.root 	126363
# Saved ../DataFrames/ttbar-4_DF.pkl
# Loading ../Files/INPUT/Diboson-0.root
# Number of events in ../Files/INPUT/Diboson-0.root 	1229420
# Saved ../DataFrames/Diboson-0_DF.pkl
# Loading ../Files/INPUT/Wjets-5.root
# Number of events in ../Files/INPUT/Wjets-5.root 	715
# Saved ../DataFrames/Wjets-5_DF.pkl
# Loading ../Files/INPUT/Zjets-0.root
# Number of events in ../Files/INPUT/Zjets-0.root 	368431
# Saved ../DataFrames/Zjets-0_DF.pkl
# Loading ../Files/INPUT/ttbar-5.root
# Number of events in ../Files/INPUT/ttbar-5.root 	106989
# Saved ../DataFrames/ttbar-5_DF.pkl
# Loading ../Files/INPUT/ttbar-2.root
# NO Keys in  ttbar-2
# Loading ../Files/INPUT/Zjets-3.root
# Number of events in ../Files/INPUT/Zjets-3.root 	2304597
# Saved ../DataFrames/Zjets-3_DF.pkl
# Loading ../Files/INPUT/ttbar-3.root
# Number of events in ../Files/INPUT/ttbar-3.root 	126798
# Saved ../DataFrames/ttbar-3_DF.pkl
# Loading ../Files/INPUT/Zjets-6.root
# Number of events in ../Files/INPUT/Zjets-6.root 	2868445
# Saved ../DataFrames/Zjets-6_DF.pkl
# Loading ../Files/INPUT/Diboson-1.root
# Number of events in ../Files/INPUT/Diboson-1.root 	576418
# Saved ../DataFrames/Diboson-1_DF.pkl
# Loading ../Files/INPUT/Wjets-0.root
# Number of events in ../Files/INPUT/Wjets-0.root 	3
# Saved ../DataFrames/Wjets-0_DF.pkl
# Loading ../Files/INPUT/ttbar-1.root
# Number of events in ../Files/INPUT/ttbar-1.root 	68987
# Saved ../DataFrames/ttbar-1_DF.pkl
# Loading ../Files/INPUT/Zjets-7.root
# Number of events in ../Files/INPUT/Zjets-7.root 	1976530
# Saved ../DataFrames/Zjets-7_DF.pkl
# Loading ../Files/INPUT/Zjets-5.root
# Number of events in ../Files/INPUT/Zjets-5.root 	2541030
# Saved ../DataFrames/Zjets-5_DF.pkl
# Loading ../Files/INPUT/ttbar-6.root
# Number of events in ../Files/INPUT/ttbar-6.root 	74898
# Saved ../DataFrames/ttbar-6_DF.pkl
# Loading ../Files/INPUT/Zjets-2.root
# Number of events in ../Files/INPUT/Zjets-2.root 	2935567
# Saved ../DataFrames/Zjets-2_DF.pkl
# Loading ../Files/INPUT/stop-0.root
# Number of events in ../Files/INPUT/stop-0.root 	9184
# Saved ../DataFrames/stop-0_DF.pkl
# Loading ../Files/INPUT/Wjets-7.root
# Number of events in ../Files/INPUT/Wjets-7.root 	17
# Saved ../DataFrames/Wjets-7_DF.pkl
# Loading ../Files/INPUT/Wjets-1.root
# Number of events in ../Files/INPUT/Wjets-1.root 	55
# Saved ../DataFrames/Wjets-1_DF.pkl
# Loading ../Files/INPUT/Zjets-1.root
# Number of events in ../Files/INPUT/Zjets-1.root 	2151895
# Saved ../DataFrames/Zjets-1_DF.pkl
# Loading ../Files/INPUT/Zjets-9.root
# Number of events in ../Files/INPUT/Zjets-9.root 	367
# Saved ../DataFrames/Zjets-9_DF.pkl
# Loading ../Files/INPUT/Wjets-2.root
# Number of events in ../Files/INPUT/Wjets-2.root 	62
# Saved ../DataFrames/Wjets-2_DF.pkl
# Loading ../Files/INPUT/Zjets-8.root
# Number of events in ../Files/INPUT/Zjets-8.root 	43428
# Saved ../DataFrames/Zjets-8_DF.pkl
# Loading ../Files/INPUT/Wjets-8.root
# Number of events in ../Files/INPUT/Wjets-8.root 	103
# Saved ../DataFrames/Wjets-8_DF.pkl
# Loading ../Files/INPUT/Wjets-6.root
# Number of events in ../Files/INPUT/Wjets-6.root 	523
# Saved ../DataFrames/Wjets-6_DF.pkl
# Loading ../Files/INPUT/Wjets-4.root
# Number of events in ../Files/INPUT/Wjets-4.root 	466
# Saved ../DataFrames/Wjets-4_DF.pkl
# Loading ../Files/INPUT/VBFHVTWZ-1.root
# Number of events in ../Files/INPUT/VBFHVTWZ-1.root 	153197
# Saved ../DataFrames/VBFHVTWZ-1_DF.pkl
# Loading ../Files/INPUT/Radion-0.root
# Number of events in ../Files/INPUT/Radion-0.root 	238661
# Saved ../DataFrames/Radion-0_DF.pkl
# Loading ../Files/INPUT/VBFRSG-0.root
# Number of events in ../Files/INPUT/VBFRSG-0.root 	209228
# Saved ../DataFrames/VBFRSG-0_DF.pkl
# Loading ../Files/INPUT/RSG-0.root
# Number of events in ../Files/INPUT/RSG-0.root 	116868
# Saved ../DataFrames/RSG-0_DF.pkl
# Loading ../Files/INPUT/VBFHVTWZ-0.root
# Number of events in ../Files/INPUT/VBFHVTWZ-0.root 	133729
# Saved ../DataFrames/VBFHVTWZ-0_DF.pkl
# Loading ../Files/INPUT/RSG-1.root
# NO Keys in  RSG-1
# Loading ../Files/INPUT/VBFRadion-0.root
# Number of events in ../Files/INPUT/VBFRadion-0.root 	239173
# Saved ../DataFrames/VBFRadion-0_DF.pkl
